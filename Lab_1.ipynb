# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed-bahaa/APIs/blob/master/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/telecom_churn.csv')
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1       2.70
# 1         0           107                1         1       3.70
# 2         0           137                1         0       0.00
# 3         0            84                0         0       0.00
# 4         0            75                0         0       0.00
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# 1                 1    161.6       123           82.0        9.78      13.7
# 2                 0    243.4       114           52.0        6.06      12.2
# 3                 2    299.4        71           57.0        3.10       6.6
# 4                 3    166.7       113           41.0        7.42      10.1
# ...             ...      ...       ...            ...         ...       ...
# 3328              2    156.2        77           71.7       10.78       9.9
# 3329              3    231.1        57           56.4        7.67       9.6
# 3330              2    180.8       109           56.0       14.44      14.1
# 3331              2    213.8       105           50.0        7.98       5.0
# 3332              0    234.4       113          100.0       13.30      13.7
#
# [3333 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Churn              0
# AccountWeeks       0
# ContractRenewal    0
# DataPlan           0
# DataUsage          0
# CustServCalls      0
# DayMins            0
# DayCalls           0
# MonthlyCharge      0
# OverageFee         0
# RoamMins           0
# dtype: int64

# %%
x=df.drop(['Churn'],axis=1)
y=df['Churn']

# %%
x
# Out:
#       AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0              128                1         1       2.70              1
# 1              107                1         1       3.70              1
# 2              137                1         0       0.00              0
# 3               84                0         0       0.00              2
# 4               75                0         0       0.00              3
# ...            ...              ...       ...        ...            ...
# 3328           192                1         1       2.67              2
# 3329            68                1         0       0.34              3
# 3330            28                1         0       0.00              2
# 3331           184                0         0       0.00              2
# 3332            74                1         1       3.70              0
#
#       DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0       265.1       110           89.0        9.87      10.0
# 1       161.6       123           82.0        9.78      13.7
# 2       243.4       114           52.0        6.06      12.2
# 3       299.4        71           57.0        3.10       6.6
# 4       166.7       113           41.0        7.42      10.1
# ...       ...       ...            ...         ...       ...
# 3328    156.2        77           71.7       10.78       9.9
# 3329    231.1        57           56.4        7.67       9.6
# 3330    180.8       109           56.0       14.44      14.1
# 3331    213.8       105           50.0        7.98       5.0
# 3332    234.4       113          100.0       13.30      13.7
#
# [3333 rows x 10 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_test
# Out:
#       AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 438            113                1         0       0.00              1
# 2674            67                1         0       0.00              0
# 1345            98                1         0       0.00              4
# 1957           147                1         0       0.33              1
# 2148            96                1         0       0.30              1
# ...            ...              ...       ...        ...            ...
# 2577           157                1         0       0.00              2
# 2763           116                1         1       2.21              3
# 3069           148                1         1       2.67              1
# 1468            75                1         1       1.13              3
# 582            104                1         0       0.00              1
#
#       DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 438     155.0        93           55.0       16.53      13.5
# 2674    109.1       117           38.0       10.87      12.8
# 1345      0.0         0           14.0        7.98       6.8
# 1957    212.8        79           57.3       10.21      10.2
# 2148    144.0       102           47.0       11.24      10.0
# ...       ...       ...            ...         ...       ...
# 2577    185.1        92           50.0       10.65       8.5
# 2763    155.7       104           65.1        9.27       8.2
# 3069    158.7        91           67.7        8.03       9.9
# 1468    117.5       102           49.3       10.34       4.2
# 582     164.2       109           42.0        7.77      10.7
#
# [667 rows x 10 columns]
